# %% [markdown]
# # ANALISIS EXPLORATORIO  DE DATOS EDA 2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Lectura de archivos

df1 = pd.read_csv('Sales_Data/Sales_January_2019.csv')
df2 = pd.read_csv('Sales_Data/Sales_February_2019.csv')
df3 = pd.read_csv('Sales_Data/Sales_March_2019.csv')
df4 = pd.read_csv('Sales_Data/Sales_April_2019.csv')
df5 = pd.read_csv('Sales_Data/Sales_May_2019.csv')
df6 = pd.read_csv('Sales_Data/Sales_June_2019.csv')
df7 = pd.read_csv('Sales_Data/Sales_July_2019.csv')
df8 = pd.read_csv('Sales_Data/Sales_August_2019.csv')
df9 = pd.read_csv('Sales_Data/Sales_September_2019.csv')
df10 = pd.read_csv('Sales_Data/Sales_October_2019.csv')
df11 = pd.read_csv('Sales_Data/Sales_November_2019.csv')
df12 = pd.read_csv('Sales_Data/Sales_December_2019.csv')

# %%
df1.sample(5)
# Out:
#      Order ID                     Product Quantity Ordered Price Each  \
# 8192   149041        USB-C Charging Cable                1      11.95
# 5992   146939  Bose SoundSport Headphones                1      99.99
# 6469   147389               Flatscreen TV                1        300
# 8687   149513        USB-C Charging Cable                1      11.95
# 1038   142226      AAA Batteries (4-pack)                3       2.99
#
#           Order Date                            Purchase Address
# 8192  01/29/19 15:42  237 Washington St, San Francisco, CA 94016
# 5992  01/11/19 22:05               324 Pine St, Dallas, TX 75001
# 6469  01/25/19 12:22        292 Pine St, New York City, NY 10001
# 8687  01/30/19 12:35           150 9th St, Los Angeles, CA 90001
# 1038  01/22/19 21:55             103 Willow St, Austin, TX 73301

# %%
df2.sample(5)
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 6981    157156  Lightning Charging Cable                1      14.95
# 9385    159462  Apple Airpods Headphones                1        150
# 3216    153567     AA Batteries (4-pack)                1       3.84
# 11860   161843    27in 4K Gaming Monitor                1     389.99
# 1795    152213        LG Washing Machine                1      600.0
#
#            Order Date                           Purchase Address
# 6981   02/12/19 17:53             201 Main St, Atlanta, GA 30301
# 9385   02/01/19 16:43  582 Jefferson St, San Francisco, CA 94016
# 3216   02/09/19 15:17         157 Chestnut St, Seattle, WA 98101
# 11860  02/17/19 19:24     426 Chestnut St, Los Angeles, CA 90001
# 1795   02/20/19 18:15      286 Cedar St, New York City, NY 10001

# %%
df3.sample(5)
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 7761    169420          Macbook Pro Laptop                1       1700
# 1246    163190  Bose SoundSport Headphones                1      99.99
# 13642   175033            Wired Headphones                1      11.99
# 12261   173714       AA Batteries (4-pack)                1       3.84
# 14803   176152    Lightning Charging Cable                1      14.95
#
#            Order Date                       Purchase Address
# 7761   03/07/19 19:46           88 1st St, Atlanta, GA 30301
# 1246   03/06/19 20:58  22 Willow St, San Francisco, CA 94016
# 13642  03/25/19 23:53         482 Cedar St, Boston, MA 02215
# 12261  03/21/19 18:16   357 Pine St, San Francisco, CA 94016
# 14803  03/08/19 11:11         453 Maple St, Austin, TX 73301

# %%
df4.sample(5)
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 1031    177538    AAA Batteries (4-pack)                1       2.99
# 14206   190103              20in Monitor                1     109.99
# 16029   191849      USB-C Charging Cable                1      11.95
# 15147   191006    AAA Batteries (4-pack)                2       2.99
# 17856   193595  Lightning Charging Cable                2      14.95
#
#            Order Date                      Purchase Address
# 1031   04/11/19 13:26          345 2nd St, Boston, MA 02215
# 14206  04/04/19 21:20       741 Church St, Dallas, TX 75001
# 16029  04/16/19 17:00       319 Meadow St, Boston, MA 02215
# 15147  04/02/19 16:14  437 Forest St, Los Angeles, CA 90001
# 17856  04/18/19 23:17          368 Elm St, Dallas, TX 75001

# %%
df5.sample(5)
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 1247    195272  Bose SoundSport Headphones                1      99.99
# 7880    201581            Wired Headphones                1      11.99
# 9396    203018             Vareebadd Phone                1        400
# 10448   204012            Wired Headphones                1      11.99
# 10443   204007      AAA Batteries (4-pack)                2       2.99
#
#            Order Date                          Purchase Address
# 1247   05/01/19 10:32     301 South St, San Francisco, CA 94016
# 7880   05/03/19 15:53           796 South St, Atlanta, GA 30301
# 9396   05/25/19 09:42      139 Wilson St, Los Angeles, CA 90001
# 10448  05/14/19 08:19  511 Highland St, New York City, NY 10001
# 10443  05/08/19 16:32      946 11th St, New York City, NY 10001

# %%
df6.sample(5)
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 3902    213627  Bose SoundSport Headphones                1      99.99
# 6859    216449            Wired Headphones                2      11.99
# 10538   219970    Lightning Charging Cable                1      14.95
# 1398    211249      AAA Batteries (4-pack)                1       2.99
# 5553    215187               Flatscreen TV                1        300
#
#            Order Date                          Purchase Address
# 3902   06/28/19 08:28          256 Meadow St, Atlanta, GA 30301
# 6859   06/04/19 10:09     652 Cedar St, San Francisco, CA 94016
# 10538  06/08/19 12:05  975 Highland St, New York City, NY 10001
# 1398   06/19/19 14:55     357 Dogwood St, Los Angeles, CA 90001
# 5553   06/15/19 23:09      476 Hill St, San Francisco, CA 94016

# %%
df7.sample(5)
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 13471   235807       AA Batteries (4-pack)                2       3.84
# 3280    226048      AAA Batteries (4-pack)                1       2.99
# 1120    223987        USB-C Charging Cable                2      11.95
# 2934    225725      AAA Batteries (4-pack)                5       2.99
# 9011    231523  Bose SoundSport Headphones                1      99.99
#
#            Order Date                        Purchase Address
# 13471  07/26/19 13:43     948 5th St, New York City, NY 10001
# 3280   07/09/19 15:41        40 Hickory St, Atlanta, GA 30301
# 1120   07/10/19 19:39  999 Cherry St, San Francisco, CA 94016
# 2934   07/30/19 00:17      929 14th St, Los Angeles, CA 90001
# 9011   07/08/19 15:42  178 Spruce St, San Francisco, CA 94016

# %%
df8.sample(5)
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 1084    237715  Apple Airpods Headphones                1        150
# 4786    241263      USB-C Charging Cable                1      11.95
# 4844    241319    AAA Batteries (4-pack)                1       2.99
# 10276   246503    AAA Batteries (4-pack)                2       2.99
# 2881    239429    AAA Batteries (4-pack)                2       2.99
#
#            Order Date                            Purchase Address
# 1084   08/25/19 21:18              77 Willow St, Boston, MA 02215
# 4786   08/18/19 14:40         417 2nd St, New York City, NY 10001
# 4844   08/22/19 13:32       202 Adams St, New York City, NY 10001
# 10276  08/26/19 19:26            144 Jackson St, Boston, MA 02215
# 2881   08/06/19 10:46  643 Washington St, New York City, NY 10001

# %%
df9.sample(5)
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 9706    257467     AA Batteries (4-pack)                2       3.84
# 10149   257885  Lightning Charging Cable                1      14.95
# 4512    252485     AA Batteries (4-pack)                1       3.84
# 7006    254867          Wired Headphones                1      11.99
# 1388    249483    27in 4K Gaming Monitor                1     389.99
#
#            Order Date                       Purchase Address
# 9706   09/27/19 15:10    89 Park St, San Francisco, CA 94016
# 10149  09/27/19 12:15   450 14th St, San Francisco, CA 94016
# 4512   09/24/19 12:10  593 Adams St, San Francisco, CA 94016
# 7006   09/15/19 07:48    262 South St, Los Angeles, CA 90001
# 1388   09/11/19 15:12     908 14th St, Los Angeles, CA 90001

# %%
df10.sample(5)
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 1937    261201  Bose SoundSport Headphones                1      99.99
# 17183   275745        USB-C Charging Cable                2      11.95
# 11169   270018      27in 4K Gaming Monitor                1     389.99
# 16929   275506        USB-C Charging Cable                2      11.95
# 17506   276053            27in FHD Monitor                1     149.99
#
#            Order Date                      Purchase Address
# 1937   10/21/19 12:36        132 13th St, Atlanta, GA 30301
# 17183  10/06/19 14:57         181 14th St, Dallas, TX 75001
# 11169  10/21/19 10:00  926 Willow St, Los Angeles, CA 90001
# 16929  10/31/19 12:32       825 Cedar St, Seattle, WA 98101
# 17506  10/30/19 15:29     146 4th St, Los Angeles, CA 90001

# %%
df11.sample(5)
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 9573    287952  Apple Airpods Headphones                1        150
# 6757    285255          Wired Headphones                1      11.99
# 7409    285881                    iPhone                1        700
# 11147   289446  Lightning Charging Cable                1      14.95
# 9208    287597          Wired Headphones                1      11.99
#
#            Order Date                        Purchase Address
# 9573   11/13/19 09:47         415 Maple St, Seattle, WA 98101
# 6757   11/30/19 20:40  163 Meadow St, San Francisco, CA 94016
# 7409   11/17/19 21:09         99 Spruce St, Seattle, WA 98101
# 11147  11/23/19 21:25     39 West St, New York City, NY 10001
# 9208   11/26/19 19:54   151 Ridge St, San Francisco, CA 94016

# %%
df12.sample(5)
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 23127   317755            Wired Headphones                1      11.99
# 22002   316682                Google Phone                1        600
# 14299   309310  Bose SoundSport Headphones                1      99.99
# 17364   312261                Google Phone                1        600
# 24807   319369            Wired Headphones                1      11.99
#
#            Order Date                      Purchase Address
# 23127  12/18/19 18:16   768 Cedar St, Los Angeles, CA 90001
# 22002  12/25/19 18:02         505 5th St, Atlanta, GA 30301
# 14299  12/27/19 14:57  815 14th St, New York City, NY 10001
# 17364  12/16/19 23:52        48 North St, Seattle, WA 98101
# 24807  12/07/19 17:58       997 Wilson St, Boston, MA 02215

# %%
#Generacion de un solo dataset
df = df1
#Genera un campo fecha
df['Month'] = '2019-01-01'

# %%
df.sample(5)
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 7810   148677  Lightning Charging Cable                2      14.95
# 842    142040  Lightning Charging Cable                1      14.95
# 3598   144650     AA Batteries (4-pack)                2       3.84
# 1062   142249  Lightning Charging Cable                1      14.95
# 4972   145956    34in Ultrawide Monitor                1     379.99
#
#           Order Date                        Purchase Address       Month
# 7810  01/19/19 09:18          478 Lake St, Atlanta, GA 30301  2019-01-01
# 842   01/30/19 20:38  874 Church St, San Francisco, CA 94016  2019-01-01
# 3598  01/08/19 10:30           301 13th St, Boston, MA 02215  2019-01-01
# 1062  01/20/19 00:07            819 6th St, Boston, MA 02215  2019-01-01
# 4972  01/27/19 12:44      177 Hill St, Los Angeles, CA 90001  2019-01-01

# %%
#Feb
df = pd.concat([df, df2], ignore_index=True)
df['Month'] = df['Month'].fillna('2019-02-01')

df.sample(20)
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 10228   150982    Lightning Charging Cable                1      14.95
# 18181   158572    Apple Airpods Headphones                1        150
# 10836   151568                Google Phone                2        600
# 16941   157377  Bose SoundSport Headphones                1      99.99
# 13246   153861                      iPhone                1        700
# 6047    146989        USB-C Charging Cable                1      11.95
# 12312   152970        USB-C Charging Cable                1      11.95
# 21615   161873    Lightning Charging Cable                1      14.95
# 3551    144605                Google Phone                1        600
# 10822   151554    Lightning Charging Cable                1      14.95
# 11216   151928        USB-C Charging Cable                1      11.95
# 2422    143532        USB-C Charging Cable                1      11.95
# 15073   155602  Bose SoundSport Headphones                1      99.99
# 5000    145982            27in FHD Monitor                1     149.99
# 6083    147022    Lightning Charging Cable                3      14.95
# 5674    146632       AA Batteries (4-pack)                1       3.84
# 52      141285      AAA Batteries (4-pack)                3       2.99
# 1093    142278        USB-C Charging Cable                1      11.95
# 9881    150654            Wired Headphones                1      11.99
# 12261   152922      AAA Batteries (4-pack)                1       2.99
#
#            Order Date                          Purchase Address       Month
# 10228  02/22/19 17:18            301 West St, Atlanta, GA 30301  2019-02-01
# 18181  02/18/19 00:11            303 Park St, Seattle, WA 98101  2019-02-01
# 10836  02/17/19 15:41    463 Highland St, Los Angeles, CA 90001  2019-02-01
# 16941  02/09/19 21:28         734 Dogwood St, Atlanta, GA 30301  2019-02-01
# 13246  02/13/19 22:09              342 Elm St, Boston, MA 02215  2019-02-01
# 6047   01/01/19 21:52    793 Chestnut St, Los Angeles, CA 90001  2019-01-01
# 12312  02/15/19 19:27    898 Center St, San Francisco, CA 94016  2019-02-01
# 21615  02/26/19 14:58    216 Sunset St, San Francisco, CA 94016  2019-02-01
# 3551   01/16/19 12:37  233 Lakeview St, New York City, NY 10001  2019-01-01
# 10822  02/03/19 22:56       476 7th St, San Francisco, CA 94016  2019-02-01
# 11216  02/10/19 20:28           692 Willow St, Boston, MA 02215  2019-02-01
# 2422   01/07/19 13:16          607 Walnut St, Atlanta, GA 30301  2019-01-01
# 15073  02/26/19 10:01     186 Cedar St, New York City, NY 10001  2019-02-01
# 5000   01/31/19 14:04            546 Main St, Atlanta, GA 30301  2019-01-01
# 6083   01/27/19 00:12       540 North St, Los Angeles, CA 90001  2019-01-01
# 5674   01/06/19 13:55        70 Jefferson St, Atlanta, GA 30301  2019-01-01
# 52     01/14/19 14:13           447 Cedar St, Seattle, WA 98101  2019-01-01
# 1093   01/12/19 15:43         655 Elm St, Los Angeles, CA 90001  2019-01-01
# 9881   02/14/19 19:10      263 Cherry St, Los Angeles, CA 90001  2019-02-01
# 12261  02/09/19 21:02           507 Ridge St, Seattle, WA 98101  2019-02-01

# %%
#Se unen los demas meses


#Mar
df = pd.concat([df, df3], ignore_index=True)
df['Month'] = df['Month'].fillna('2019-03-01')

#Abr
df = pd.concat([df, df4], ignore_index=True)
df['Month'] = df['Month'].fillna('2019-04-01')

#May
df = pd.concat([df, df5], ignore_index=True)
df['Month'] = df['Month'].fillna('2019-05-01')

#Jun
df = pd.concat([df, df6], ignore_index=True)
df['Month'] = df['Month'].fillna('2019-06-01')

#Jul
df = pd.concat([df, df7], ignore_index=True)
df['Month'] = df['Month'].fillna('2019-07-01')

#Ago
df = pd.concat([df, df8], ignore_index=True)
df['Month'] = df['Month'].fillna('2019-08-01')

#Sep
df = pd.concat([df, df9], ignore_index=True)
df['Month'] = df['Month'].fillna('2019-09-01')

#Oct
df = pd.concat([df, df10], ignore_index=True)
df['Month'] = df['Month'].fillna('2019-10-01')

#Nov
df = pd.concat([df, df11], ignore_index=True)
df['Month'] = df['Month'].fillna('2019-11-01')

#dic
df = pd.concat([df, df12], ignore_index=True)
df['Month'] = df['Month'].fillna('2019-12-01')

# %%
df.sample(20)
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 108326   244637       AA Batteries (4-pack)                1       3.84
# 28797    168729      AAA Batteries (4-pack)                1       2.99
# 142276   277082        USB-C Charging Cable                1      11.95
# 63693    202005      34in Ultrawide Monitor                1     379.99
# 43140    182440            27in FHD Monitor                1     149.99
# 142362   277163    Lightning Charging Cable                1      14.95
# 43273    182568                      iPhone                1        700
# 91705    228725                Google Phone                1        600
# 58946    197493                      iPhone                1        700
# 178299   311500    Lightning Charging Cable                1      14.95
# 140524   275413                20in Monitor                1     109.99
# 44974    184183  Bose SoundSport Headphones                1      99.99
# 68203    206296    Apple Airpods Headphones                1        150
# 25993    166033            Wired Headphones                1      11.99
# 23187    163364                      iPhone                1        700
# 37546    177096        USB-C Charging Cable                1      11.95
# 103436   239975  Bose SoundSport Headphones                1      99.99
# 32838    172591      34in Ultrawide Monitor                1     379.99
# 88059    225250                Google Phone                1        600
# 66150    204334    Lightning Charging Cable                1      14.95
#
#             Order Date                         Purchase Address       Month
# 108326  08/11/19 11:08          289 Spruce St, Dallas, TX 75001  2019-08-01
# 28797   03/31/19 13:56  377 Madison St, New York City, NY 10001  2019-03-01
# 142276  10/30/19 18:04            682 14th St, Dallas, TX 75001  2019-10-01
# 63693   05/19/19 23:27             25 12th St, Boston, MA 02215  2019-05-01
# 43140   04/07/19 08:32          283 Wilson St, Austin, TX 73301  2019-04-01
# 142362  10/03/19 07:28        576 Center St, Portland, ME 04101  2019-10-01
# 43273   04/26/19 20:34    641 River St, New York City, NY 10001  2019-04-01
# 91705   07/05/19 17:32            317 7th St, Seattle, WA 98101  2019-07-01
# 58946   05/06/19 10:13    239 South St, San Francisco, CA 94016  2019-05-01
# 178299  12/10/19 14:09           910 11th St, Atlanta, GA 30301  2019-12-01
# 140524  10/20/19 11:38             976 Elm St, Boston, MA 02215  2019-10-01
# 44974   04/18/19 15:31         176 Meadow St, Atlanta, GA 30301  2019-04-01
# 68203   05/02/19 11:24           993 North St, Austin, TX 73301  2019-05-01
# 25993   03/30/19 11:56            841 5th St, Atlanta, GA 30301  2019-03-01
# 23187   03/15/19 11:26       573 12th St, Los Angeles, CA 90001  2019-03-01
# 37546   04/06/19 19:49          115 Church St, Dallas, TX 75001  2019-04-01
# 103436  08/04/19 17:35            120 Hill St, Boston, MA 02215  2019-08-01
# 32838   03/16/19 09:33         382 North St, Portland, OR 97035  2019-03-01
# 88059   07/03/19 08:41             870 4th St, Boston, MA 02215  2019-07-01
# 66150   05/01/19 22:29      441 8th St, New York City, NY 10001  2019-05-01

# %%
df.groupby('Month')['Month'].count()
# Out:
# Month
# 2019-01-01     9723
# 2019-02-01    12036
# 2019-03-01    15226
# 2019-04-01    18383
# 2019-05-01    16635
# 2019-06-01    13622
# 2019-07-01    14371
# 2019-08-01    12011
# 2019-09-01    11686
# 2019-10-01    20379
# 2019-11-01    17661
# 2019-12-01    25117
# Name: Month, dtype: int64

# %%
df.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count     186305                186305           186305     186305
# unique    178438                    20               10         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq         355                 21903           168552      21903
#
#         Order Date  Purchase Address       Month
# count       186305            186305      186850
# unique      142396            140788          12
# top     Order Date  Purchase Address  2019-12-01
# freq           355               355       25117

# %%
df.groupby('Product')['Product'].count()
# Out:
# Product
# 20in Monitor                   4101
# 27in 4K Gaming Monitor         6230
# 27in FHD Monitor               7507
# 34in Ultrawide Monitor         6181
# AA Batteries (4-pack)         20577
# AAA Batteries (4-pack)        20641
# Apple Airpods Headphones      15549
# Bose SoundSport Headphones    13325
# Flatscreen TV                  4800
# Google Phone                   5525
# LG Dryer                        646
# LG Washing Machine              666
# Lightning Charging Cable      21658
# Macbook Pro Laptop             4724
# Product                         355
# ThinkPad Laptop                4128
# USB-C Charging Cable          21903
# Vareebadd Phone                2065
# Wired Headphones              18882
# iPhone                         6842
# Name: Product, dtype: int64

# %% [markdown]
# ## Masajeo de Datos

# %%
# Elimina nulos
df = df.dropna(how='all')

# %%
df['Order Date']
# Out:
# 0         01/22/19 21:25
# 1         01/28/19 14:15
# 2         01/17/19 13:33
# 3         01/05/19 20:33
# 4         01/25/19 11:59
#                ...
# 186845    12/11/19 20:58
# 186846    12/01/19 12:01
# 186847    12/09/19 06:43
# 186848    12/03/19 10:39
# 186849    12/21/19 21:45
# Name: Order Date, Length: 186850, dtype: object

# %%
#Elimina cadenas especiales para fecha de pedido
df = df[df['Order Date'].str[0:2] != 'Or']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 186495 entries, 0 to 186849
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  object
#  3   Price Each        185950 non-null  object
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             186495 non-null  object
# dtypes: object(7)
# memory usage: 11.4+ MB

# %%
#Tipos de datos
df['Month'] = pd.to_datetime(df['Month'])
df['Order Date'] = pd.to_datetime(df['Order Date'])
# Out:
# C:\Users\paob2\AppData\Local\Temp\ipykernel_63988\248978368.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 186495 entries, 0 to 186849
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  object
#  3   Price Each        185950 non-null  object
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  185950 non-null  object
#  6   Month             186495 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), object(5)
# memory usage: 11.4+ MB

# %%
# tener cuidado con las cantidades
df['Quantity Ordered'].unique()
# Out:
# array(['1', '2', '3', '5', '4', nan, '7', '6', '9', '8'], dtype=object)

# %%
#Conversion de columnas numéricas
df['Order ID'] = df['Order ID'].astype('string')

df['Product'] = df['Product'].astype('string')

df['Quantity Ordered'] = df['Quantity Ordered'].fillna(0)
df['Quantity Ordered'] = df['Quantity Ordered'].astype('int64')

df['Price Each'] = df['Price Each'].astype('float')

df['Purchase Address'] = df['Purchase Address'].astype('string')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 186495 entries, 0 to 186849
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  string
#  1   Product           185950 non-null  string
#  2   Quantity Ordered  186495 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  185950 non-null  string
#  6   Month             186495 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(1), string(3)
# memory usage: 11.4 MB

# %%
#numero de datos vacios por columna
missing_values_count = df.isnull().sum()
missing_values_count[0:10]
# Out:
# Order ID            545
# Product             545
# Quantity Ordered      0
# Price Each          545
# Order Date          545
# Purchase Address    545
# Month                 0
# dtype: int64

# %%
# eliminar esos ceros
df = df[df['Quantity Ordered'] > 0]

# %%
#numero de datos vacios por columna
missing_values_count = df.isnull().sum()
missing_values_count[0:10]
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# Month               0
# dtype: int64

# %%
pd.options.display.float_format = '{:.2f}'.format
df.describe().T
# Out:
#                      count                           mean  \
# Quantity Ordered 185950.00                           1.12
# Price Each       185950.00                         184.40
# Order Date          185950  2019-07-18 21:54:38.887550208
# Month               185950  2019-07-03 11:51:07.056735488
#
#                                   min                  25%  \
# Quantity Ordered                 1.00                 1.00
# Price Each                       2.99                11.95
# Order Date        2019-01-01 03:07:00  2019-04-16 21:05:15
# Month             2019-01-01 00:00:00  2019-04-01 00:00:00
#
#                                   50%                  75%  \
# Quantity Ordered                 1.00                 1.00
# Price Each                      14.95               150.00
# Order Date        2019-07-17 20:40:30  2019-10-26 08:14:00
# Month             2019-07-01 00:00:00  2019-10-01 00:00:00
#
#                                   max    std
# Quantity Ordered                 9.00   0.44
# Price Each                    1700.00 332.73
# Order Date        2020-01-01 05:13:00    NaN
# Month             2019-12-01 00:00:00    NaN

# %%
df['zipcode'] = df['Purchase Address'].str[-6:]
df['zipcode'].unique()
# Out:
# <StringArray>
# [' 02215', ' 97035', ' 94016', ' 90001', ' 73301', ' 30301', ' 98101',
#  ' 10001', ' 75001', ' 04101']
# Length: 10, dtype: string

# %%
df['zipcode'] = df['zipcode'].astype('string')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185950 entries, 0 to 186849
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  string
#  1   Product           185950 non-null  string
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  185950 non-null  string
#  6   Month             185950 non-null  datetime64[ns]
#  7   zipcode           185950 non-null  string
# dtypes: datetime64[ns](2), float64(1), int64(1), string(4)
# memory usage: 12.8 MB

# %% [markdown]
# # ANALISIS DE CORRELACION

# %%
#Grafica de correlacion

df_num_vars = df.select_dtypes(include=[np.number])  # selecciona solo columnnas numericas

plt.figure(figsize=(14,10))
corr_df = corr = df_num_vars.corr(method="pearson")
df_lt = corr_df.where(np.tril(np.ones(corr_df.shape)).astype(bool))
hmap=sns.heatmap(df_lt, cmap="YlGnBu", annot=True)
plt.show()

# %%
#grafica exploratoria de todas las columnas
sns.displot(df['Quantity Ordered'] , kde=False)
sns.displot(df['Price Each'] , kde=False)

# %%
#Agrupamientos

df.groupby(["Product"])['Price Each'].mean()
# Out:
# Product
# 20in Monitor                  109.99
# 27in 4K Gaming Monitor        389.99
# 27in FHD Monitor              149.99
# 34in Ultrawide Monitor        379.99
# AA Batteries (4-pack)           3.84
# AAA Batteries (4-pack)          2.99
# Apple Airpods Headphones      150.00
# Bose SoundSport Headphones     99.99
# Flatscreen TV                 300.00
# Google Phone                  600.00
# LG Dryer                      600.00
# LG Washing Machine            600.00
# Lightning Charging Cable       14.95
# Macbook Pro Laptop           1700.00
# ThinkPad Laptop               999.99
# USB-C Charging Cable           11.95
# Vareebadd Phone               400.00
# Wired Headphones               11.99
# iPhone                        700.00
# Name: Price Each, dtype: float64

# %%
df.groupby(["Product"])['Price Each']..median().sort_values(by="Price Each").plot.bar
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 df.groupby(["Product"])['Price Each'].rename("Price Each").median().sort_values(by="Price Each").plot.bar
#
# File c:\Users\paob2\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1363, in GroupBy.__getattr__(self, attr)
#    1360 if attr in self.obj:
#    1361     return self[attr]
# -> 1363 raise AttributeError(
#    1364     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'rename'
